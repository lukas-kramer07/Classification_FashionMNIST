# %% [markdown]
# <a href="https://colab.research.google.com/github/lukas-kramer07/Classification_FashionMNIST/blob/main/GFS_INF_Classification_FashionMNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Models

# %% [markdown]
# ## V1

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import numpy as np

# Create a confusion matrix
# Note: Adapted from scikit-learn's plot_confusion_matrix()

import itertools
from sklearn.metrics import confusion_matrix

class_names = ["T-shirt/top","Trousers", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle Boot"]
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10,10,), text_size=15):
  #Create the confusion matrix
  cm = confusion_matrix(y_true, tf.round(y_preds))
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
  n_classes= cm.shape[0]

  # Let's prettify it
  fig, ax = plt.subplots(figsize=figsize)
  #Create a matrix plot
  cax = ax.matshow(cm, cmap=plt.cm.Purples)
  fig.colorbar(cax)

#set labels to be classes
  labels = classes if classes else np.arange(cm.shape[0])
  # Label the axes
  ax.set(title="Confusion matrix - Fashion_modelV1",
        xlabel="Predicted label",
        ylabel="True label",
        xticks=np.arange(n_classes),
        yticks=np.arange(n_classes),
        xticklabels=labels,
        yticklabels=labels)

  # Set x-labels to the bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  #Adjust label size
  ax.xaxis.label.set_size(text_size)
  ax.yaxis.label.set_size(text_size)
  ax.title.set_size(text_size)

  # Set coluor threshhold
  threshold = (cm.max() + cm.min())/2.

  #Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, f"{cm[i, j]} ({cm_norm[i,j]*100:.1f}%)",
            horizontalalignment="center",
            color="white" if cm[i, j] > threshold else "black",
            size=text_size)







# The data has already been sorted into training and test sets 
(train_data, train_labels) , (test_data, test_labels) = fashion_mnist.load_data()


tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy",
                 optimizer=tf.keras.optimizers.Adam(),
                 metrics=["accuracy"])
norm_history = model.fit(train_data,
                          train_labels,
                          epochs=50,
                          validation_data=(test_data, test_labels))


model.save("Fashion_modelV1")

y_probs = model.predict(test_data)
y_preds = tf.argmax(y_probs, axis=1)


make_confusion_matrix(y_true=test_labels,
                      y_pred=y_preds,
                      classes=class_names,
                      figsize=(13,13),
                      text_size=8)
pd.DataFrame(norm_history.history).plot(title="Fashion_modelV1")
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
# 1875/1875 [==============================] - 10s 4ms/step - loss: 1.2201 - accuracy: 0.7517 - val_loss: 0.5669 - val_accuracy: 0.7974
# Epoch 2/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5002 - accuracy: 0.8242 - val_loss: 0.5539 - val_accuracy: 0.8182
# Epoch 3/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4442 - accuracy: 0.8419 - val_loss: 0.4846 - val_accuracy: 0.8208
# Epoch 4/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4127 - accuracy: 0.8531 - val_loss: 0.4600 - val_accuracy: 0.8407
# Epoch 5/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4014 - accuracy: 0.8551 - val_loss: 0.4378 - val_accuracy: 0.8428
# Epoch 6/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3763 - accuracy: 0.8644 - val_loss: 0.4848 - val_accuracy: 0.8231
# Epoch 7/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3645 - accuracy: 0.8694 - val_loss: 0.4265 - val_accuracy: 0.8466
# Epoch 8/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3542 - accuracy: 0.8724 - val_loss: 0.4191 - val_accuracy: 0.8542
# Epoch 9/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3453 - accuracy: 0.8756 - val_loss: 0.4040 - val_accuracy: 0.8668
# Epoch 10/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3386 - accuracy: 0.8782 - val_loss: 0.4172 - val_accuracy: 0.8593
# Epoch 11/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3337 - accuracy: 0.8789 - val_loss: 0.4135 - val_accuracy: 0.8675
# Epoch 12/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3255 - accuracy: 0.8816 - val_loss: 0.4756 - val_accuracy: 0.8534
# Epoch 13/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3218 - accuracy: 0.8846 - val_loss: 0.4213 - val_accuracy: 0.8582
# Epoch 14/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3223 - accuracy: 0.8859 - val_loss: 0.4004 - val_accuracy: 0.8761
# Epoch 15/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3134 - accuracy: 0.8863 - val_loss: 0.4113 - val_accuracy: 0.8594
# Epoch 16/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3083 - accuracy: 0.8894 - val_loss: 0.4228 - val_accuracy: 0.8616
# Epoch 17/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3024 - accuracy: 0.8897 - val_loss: 0.4204 - val_accuracy: 0.8722
# Epoch 18/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3008 - accuracy: 0.8913 - val_loss: 0.3989 - val_accuracy: 0.8746
# Epoch 19/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2949 - accuracy: 0.8924 - val_loss: 0.4427 - val_accuracy: 0.8654
# Epoch 20/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2978 - accuracy: 0.8944 - val_loss: 0.4708 - val_accuracy: 0.8689
# Epoch 21/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2943 - accuracy: 0.8943 - val_loss: 0.4502 - val_accuracy: 0.8736
# Epoch 22/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2897 - accuracy: 0.8967 - val_loss: 0.4994 - val_accuracy: 0.8701
# Epoch 23/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2883 - accuracy: 0.8958 - val_loss: 0.4393 - val_accuracy: 0.8666
# Epoch 24/50
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.2874 - accuracy: 0.8965 - val_loss: 0.5316 - val_accuracy: 0.8704
# Epoch 25/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2951 - accuracy: 0.8965 - val_loss: 0.4306 - val_accuracy: 0.8689
# Epoch 26/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2821 - accuracy: 0.8983 - val_loss: 0.4469 - val_accuracy: 0.8759
# Epoch 27/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2797 - accuracy: 0.8989 - val_loss: 0.5238 - val_accuracy: 0.8727
# Epoch 28/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2810 - accuracy: 0.8988 - val_loss: 0.8372 - val_accuracy: 0.8686
# Epoch 29/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2711 - accuracy: 0.9010 - val_loss: 0.5074 - val_accuracy: 0.8745
# Epoch 30/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2742 - accuracy: 0.9010 - val_loss: 0.4506 - val_accuracy: 0.8695
# Epoch 31/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2700 - accuracy: 0.9024 - val_loss: 0.6171 - val_accuracy: 0.8663
# Epoch 32/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2717 - accuracy: 0.9022 - val_loss: 0.5102 - val_accuracy: 0.8745
# Epoch 33/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2731 - accuracy: 0.9018 - val_loss: 0.5203 - val_accuracy: 0.8714
# Epoch 34/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2745 - accuracy: 0.9003 - val_loss: 0.4831 - val_accuracy: 0.8549
# Epoch 35/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2675 - accuracy: 0.9032 - val_loss: 0.5345 - val_accuracy: 0.8695
# Epoch 36/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2676 - accuracy: 0.9038 - val_loss: 0.4767 - val_accuracy: 0.8756
# Epoch 37/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2658 - accuracy: 0.9062 - val_loss: 0.5462 - val_accuracy: 0.8731
# Epoch 38/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2604 - accuracy: 0.9064 - val_loss: 0.5660 - val_accuracy: 0.8684
# Epoch 39/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2585 - accuracy: 0.9074 - val_loss: 0.4703 - val_accuracy: 0.8747
# Epoch 40/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2673 - accuracy: 0.9044 - val_loss: 0.6535 - val_accuracy: 0.8729
# Epoch 41/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2555 - accuracy: 0.9079 - val_loss: 0.6389 - val_accuracy: 0.8700
# Epoch 42/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2659 - accuracy: 0.9064 - val_loss: 0.6345 - val_accuracy: 0.8735
# Epoch 43/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2578 - accuracy: 0.9075 - val_loss: 0.5578 - val_accuracy: 0.8804
# Epoch 44/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2518 - accuracy: 0.9093 - val_loss: 0.5793 - val_accuracy: 0.8755
# Epoch 45/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2545 - accuracy: 0.9085 - val_loss: 0.5825 - val_accuracy: 0.8700
# Epoch 46/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2536 - accuracy: 0.9087 - val_loss: 0.6202 - val_accuracy: 0.8741
# Epoch 47/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2578 - accuracy: 0.9091 - val_loss: 0.5562 - val_accuracy: 0.8604
# Epoch 48/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2465 - accuracy: 0.9107 - val_loss: 0.6103 - val_accuracy: 0.8687
# Epoch 49/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2498 - accuracy: 0.9083 - val_loss: 0.6365 - val_accuracy: 0.8786
# Epoch 50/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2625 - accuracy: 0.9089 - val_loss: 0.5524 - val_accuracy: 0.8783
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# ## V2

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import numpy as np

# Create a confusion matrix
# Note: Adapted from scikit-learn's plot_confusion_matrix()

import itertools
from sklearn.metrics import confusion_matrix

class_names = ["T-shirt/top","Trousers", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle Boot"]
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10,10,), text_size=15):
  #Create the confusion matrix
  cm = confusion_matrix(y_true, tf.round(y_preds))
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
  n_classes= cm.shape[0]

  # Let's prettify it
  fig, ax = plt.subplots(figsize=figsize)
  #Create a matrix plot
  cax = ax.matshow(cm, cmap=plt.cm.Purples)
  fig.colorbar(cax)

#set labels to be classes
  labels = classes if classes else np.arange(cm.shape[0])
  # Label the axes
  ax.set(title="Confusion matrix - Fashion_modelV2",
        xlabel="Predicted label",
        ylabel="True label",
        xticks=np.arange(n_classes),
        yticks=np.arange(n_classes),
        xticklabels=labels,
        yticklabels=labels)

  # Set x-labels to the bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  #Adjust label size
  ax.xaxis.label.set_size(text_size)
  ax.yaxis.label.set_size(text_size)
  ax.title.set_size(text_size)

  # Set coluor threshhold
  threshold = (cm.max() + cm.min())/2.

  #Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, f"{cm[i, j]} ({cm_norm[i,j]*100:.1f}%)",
            horizontalalignment="center",
            color="white" if cm[i, j] > threshold else "black",
            size=text_size)







# The data has already been sorted into training and test sets 
(train_data, train_labels) , (test_data, test_labels) = fashion_mnist.load_data()


tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(250, activation="relu"),
    tf.keras.layers.Dense(150, activation="relu"),
    tf.keras.layers.Dense(250, activation="relu"),
    tf.keras.layers.Dense(150, activation="relu"),
    tf.keras.layers.Dense(300, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy",
                 optimizer=tf.keras.optimizers.Adam(),
                 metrics=["accuracy"])
bigger_history = model.fit(train_data,
                          train_labels,
                          epochs=50,
                          validation_data=(test_data, test_labels))


model.save("Fashion_modelV2")

y_probs = model.predict(test_data)
y_preds = tf.argmax(y_probs, axis=1)


make_confusion_matrix(y_true=test_labels,
                      y_pred=y_preds,
                      classes=class_names,
                      figsize=(13,13),
                      text_size=8)
pd.DataFrame(bigger_history.history).plot(title="Fashion_modelV2")
plt.show()
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 20s 10ms/step - loss: 0.7764 - accuracy: 0.7827 - val_loss: 0.5951 - val_accuracy: 0.7890
# Epoch 2/50
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.4659 - accuracy: 0.8336 - val_loss: 0.5115 - val_accuracy: 0.8244
# Epoch 3/50
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.4233 - accuracy: 0.8495 - val_loss: 0.4831 - val_accuracy: 0.8340
# Epoch 4/50
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.3951 - accuracy: 0.8610 - val_loss: 0.4350 - val_accuracy: 0.8499
# Epoch 5/50
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3753 - accuracy: 0.8662 - val_loss: 0.4077 - val_accuracy: 0.8566
# Epoch 6/50
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.3592 - accuracy: 0.8719 - val_loss: 0.4204 - val_accuracy: 0.8524
# Epoch 7/50
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.3449 - accuracy: 0.8778 - val_loss: 0.4006 - val_accuracy: 0.8605
# Epoch 8/50
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3375 - accuracy: 0.8802 - val_loss: 0.3807 - val_accuracy: 0.8705
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2303 - accuracy: 0.9187 - val_loss: 0.4964 - val_accuracy: 0.8766
# Epoch 47/50
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.2246 - accuracy: 0.9193 - val_loss: 0.4581 - val_accuracy: 0.8800
# Epoch 48/50
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2146 - accuracy: 0.9219 - val_loss: 0.5464 - val_accuracy: 0.8821
# Epoch 49/50
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2208 - accuracy: 0.9203 - val_loss: 0.4373 - val_accuracy: 0.8834
# Epoch 50/50
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.2167 - accuracy: 0.9225 - val_loss: 0.4596 - val_accuracy: 0.8775
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# ## V3

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np

# Create a confusion matrix
# Note: Adapted from scikit-learn's plot_confusion_matrix()

import itertools
from sklearn.metrics import confusion_matrix

class_names = ["T-shirt/top","Trousers", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle Boot"]
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10,10,), text_size=15):
  #Create the confusion matrix
  cm = confusion_matrix(y_true, tf.round(y_preds))
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
  n_classes= cm.shape[0]

  # Let's prettify it
  fig, ax = plt.subplots(figsize=figsize)
  #Create a matrix plot
  cax = ax.matshow(cm, cmap=plt.cm.Purples)
  fig.colorbar(cax)

#set labels to be classes
  labels = classes if classes else np.arange(cm.shape[0])
  # Label the axes
  ax.set(title="Confusion matrix - Fashion_modelV3",
        xlabel="Predicted label",
        ylabel="True label",
        xticks=np.arange(n_classes),
        yticks=np.arange(n_classes),
        xticklabels=labels,
        yticklabels=labels)

  # Set x-labels to the bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  #Adjust label size
  ax.xaxis.label.set_size(text_size)
  ax.yaxis.label.set_size(text_size)
  ax.title.set_size(text_size)

  # Set coluor threshhold
  threshold = (cm.max() + cm.min())/2.

  #Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, f"{cm[i, j]} ({cm_norm[i,j]*100:.1f}%)",
            horizontalalignment="center",
            color="white" if cm[i, j] > threshold else "black",
            size=text_size)







# The data has already been sorted into training and test sets 
(train_data, train_labels) , (test_data, test_labels) = fashion_mnist.load_data()
# We can normalize our training data by deviding by the max (255)
train_data_norm = train_data/255
test_data_norm = test_data/255
tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(250, activation="relu"),
    tf.keras.layers.Dense(150, activation="relu"),
    tf.keras.layers.Dense(250, activation="relu"),
    tf.keras.layers.Dense(150, activation="relu"),
    tf.keras.layers.Dense(300, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy",
                 optimizer=tf.keras.optimizers.Adam(),
                 metrics=["accuracy"])

def add_noise(image):
    noise = np.random.normal(loc=0, scale=0.02, size=image.shape)
    noisy_image = image + noise
    return np.clip(noisy_image, 0, 1)

# Create an instance of the ImageDataGenerator class for data augmentation
data_augmenter = ImageDataGenerator(
    rotation_range=10,  # rotate the image up to 10 degrees
    width_shift_range=0.05,  
    height_shift_range=0.05,  
    horizontal_flip=True,  # flip the image horizontally
    vertical_flip=False,  # do not flip the image vertically
    zoom_range=0.05,  # zoom in/out up to 5%
    fill_mode='nearest',  # fill gaps in the image with the nearest pixel
    preprocessing_function=add_noise  # Add the add_noise function as the preprocessing function
)

# Fit the data augmenter on the training data
data_augmenter.fit(tf.expand_dims(train_data_norm, 3))

# Train the model on the augmented data
augmented_history = model.fit(
    data_augmenter.flow(tf.expand_dims(train_data_norm, -1), train_labels),
    epochs=50,
    validation_data=(tf.expand_dims(test_data_norm, -1), test_labels),
    )


model.save("Fashion_modelV3")

y_probs = model.predict(test_data_norm)
y_preds = tf.argmax(y_probs, axis=1)


make_confusion_matrix(y_true=test_labels,
                      y_pred=y_preds,
                      classes=class_names,
                      figsize=(13,13),
                      text_size=8)
pd.DataFrame(augmented_history.history).plot(title="Fashion_modelV3")
plt.show()
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 52s 27ms/step - loss: 0.6846 - accuracy: 0.7414 - val_loss: 0.4942 - val_accuracy: 0.8139
# Epoch 2/50
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.5413 - accuracy: 0.7968 - val_loss: 0.4559 - val_accuracy: 0.8349
# Epoch 3/50
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.5064 - accuracy: 0.8098 - val_loss: 0.4490 - val_accuracy: 0.8281
# Epoch 4/50
# 1875/1875 [==============================] - 46s 25ms/step - loss: 0.4787 - accuracy: 0.8192 - val_loss: 0.4321 - val_accuracy: 0.8440
# Epoch 5/50
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.4614 - accuracy: 0.8272 - val_loss: 0.4186 - val_accuracy: 0.8475
# Epoch 6/50
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.4441 - accuracy: 0.8345 - val_loss: 0.4290 - val_accuracy: 0.8401
# Epoch 7/50
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.4357 - accuracy: 0.8370 - val_loss: 0.3891 - val_accuracy: 0.8554
# Epoch 8/50
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.4281 - accuracy: 0.8406 - val_loss: 0.4252 - val_accuracy: 0.8450
# Epoch 9/50
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.4202 - accuracy: 0.8443 - val_loss: 0.3848 - val_accuracy: 0.8556
# Epoch 10/50
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.4164 - accuracy: 0.8435 - val_loss: 0.3801 - val_accuracy: 0.8620
# Epoch 11/50
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.4077 - accuracy: 0.8471 - val_loss: 0.3895 - val_accuracy: 0.8549
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# ## V4

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.callbacks import LearningRateScheduler

# Create a confusion matrix
# Note: Adapted from scikit-learn's plot_confusion_matrix()

import itertools
from sklearn.metrics import confusion_matrix

class_names = ["T-shirt/top","Trousers", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle Boot"]
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10,10,), text_size=15):
  #Create the confusion matrix
  cm = confusion_matrix(y_true, tf.round(y_preds))
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
  n_classes= cm.shape[0]

  # Let's prettify it
  fig, ax = plt.subplots(figsize=figsize)
  #Create a matrix plot
  cax = ax.matshow(cm, cmap=plt.cm.Purples)
  fig.colorbar(cax)

#set labels to be classes
  labels = classes if classes else np.arange(cm.shape[0])
  # Label the axes
  ax.set(title="Confusion matrix",
        xlabel="Predicted label",
        ylabel="True label",
        xticks=np.arange(n_classes),
        yticks=np.arange(n_classes),
        xticklabels=labels,
        yticklabels=labels)

  # Set x-labels to the bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  #Adjust label size
  ax.xaxis.label.set_size(text_size)
  ax.yaxis.label.set_size(text_size)
  ax.title.set_size(text_size)

  # Set coluor threshhold
  threshold = (cm.max() + cm.min())/2.

  #Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, f"{cm[i, j]} ({cm_norm[i,j]*100:.1f}%)",
            horizontalalignment="center",
            color="white" if cm[i, j] > threshold else "black",
            size=text_size)







# The data has already been sorted into training and test sets 
(train_data, train_labels) , (test_data, test_labels) = fashion_mnist.load_data()
# We can normalize our training data by deviding by the max (255)
train_data_norm = train_data/255
test_data_norm = test_data/255
tf.random.set_seed(42)

# Define a function that decreases the learning rate
def lr_schedule(epoch, lr):
  return lr * 0.4 if epoch % 15 == 0 and epoch > 15 else lr

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(250, activation="relu"),
    tf.keras.layers.Dense(150, activation="relu"),
    tf.keras.layers.Dense(250, activation="relu"),
    tf.keras.layers.Dense(150, activation="relu"),
    tf.keras.layers.Dense(300, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy",
                 optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                 metrics=["accuracy"])

# Define the learning rate scheduler callback
lr_scheduler = LearningRateScheduler(lr_schedule)


#Data Augmentation
def add_noise(image):
    noise = np.random.normal(loc=0, scale=0.02, size=image.shape)
    noisy_image = image + noise
    return np.clip(noisy_image, 0, 1)

# Create an instance of the ImageDataGenerator class for data augmentation
data_augmenter = ImageDataGenerator(
    rotation_range=10,  # rotate the image up to 10 degrees
    width_shift_range=0.05,  
    height_shift_range=0.05,  
    horizontal_flip=True,  # flip the image horizontally
    vertical_flip=False,  # do not flip the image vertically
    zoom_range=0.05,  # zoom in/out up to 5%
    fill_mode='nearest',  # fill gaps in the image with the nearest pixel
    preprocessing_function=add_noise  # Add the add_noise function as the preprocessing function
)

# Fit the data augmenter on the training data
data_augmenter.fit(tf.expand_dims(train_data_norm, 3))

# Train the model on the augmented data
augmented_history = model.fit(
    data_augmenter.flow(tf.expand_dims(train_data_norm, -1), train_labels),
    epochs=100,
    validation_data=(tf.expand_dims(test_data_norm, -1), test_labels),
    callbacks=[lr_scheduler]
    )


model.save("Fashion_modelV4")

y_probs = model.predict(test_data_norm)
y_preds = tf.argmax(y_probs, axis=1)


make_confusion_matrix(y_true=test_labels,
                      y_pred=y_preds,
                      classes=class_names,
                      figsize=(13,13),
                      text_size=8)
pd.DataFrame(augmented_history.history).plot(title="Non-normalized data")
plt.show()
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 48s 25ms/step - loss: 0.6854 - accuracy: 0.7397 - val_loss: 0.5081 - val_accuracy: 0.8115 - lr: 0.0010
# Epoch 2/100
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.5425 - accuracy: 0.7954 - val_loss: 0.4695 - val_accuracy: 0.8336 - lr: 0.0010
# Epoch 3/100
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.5001 - accuracy: 0.8122 - val_loss: 0.4304 - val_accuracy: 0.8376 - lr: 0.0010
# Epoch 4/100
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.4776 - accuracy: 0.8219 - val_loss: 0.4876 - val_accuracy: 0.8136 - lr: 0.0010
# Epoch 5/100
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.4612 - accuracy: 0.8264 - val_loss: 0.4315 - val_accuracy: 0.8418 - lr: 0.0010
# Epoch 6/100
# 1875/1875 [==============================] - 48s 25ms/step - loss: 0.4428 - accuracy: 0.8330 - val_loss: 0.4032 - val_accuracy: 0.8484 - lr: 0.0010
# Epoch 7/100
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.4343 - accuracy: 0.8367 - val_loss: 0.4044 - val_accuracy: 0.8573 - lr: 0.0010
# Epoch 8/100
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.4238 - accuracy: 0.8424 - val_loss: 0.3956 - val_accuracy: 0.8562 - lr: 0.0010
# Epoch 9/100
# 1875/1875 [==============================] - 48s 25ms/step - loss: 0.4170 - accuracy: 0.8458 - val_loss: 0.3941 - val_accuracy: 0.8525 - lr: 0.0010
# Epoch 10/100
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.4099 - accuracy: 0.8469 - val_loss: 0.3785 - val_accuracy: 0.8633 - lr: 0.0010
# Epoch 11/100
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.4039 - accuracy: 0.8494 - val_loss: 0.3968 - val_accuracy: 0.8518 - lr: 0.0010
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.2567 - accuracy: 0.9012 - val_loss: 0.3390 - val_accuracy: 0.8888 - lr: 1.0240e-05
# Epoch 94/100
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.2567 - accuracy: 0.9013 - val_loss: 0.3374 - val_accuracy: 0.8894 - lr: 1.0240e-05
# Epoch 95/100
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.2572 - accuracy: 0.8998 - val_loss: 0.3405 - val_accuracy: 0.8890 - lr: 1.0240e-05
# Epoch 96/100
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.2568 - accuracy: 0.9004 - val_loss: 0.3392 - val_accuracy: 0.8879 - lr: 1.0240e-05
# Epoch 97/100
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.2560 - accuracy: 0.9017 - val_loss: 0.3407 - val_accuracy: 0.8891 - lr: 1.0240e-05
# Epoch 98/100
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.2559 - accuracy: 0.9011 - val_loss: 0.3401 - val_accuracy: 0.8892 - lr: 1.0240e-05
# Epoch 99/100
# 1875/1875 [==============================] - 51s 27ms/step - loss: 0.2566 - accuracy: 0.9007 - val_loss: 0.3395 - val_accuracy: 0.8884 - lr: 1.0240e-05
# Epoch 100/100
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.2569 - accuracy: 0.9004 - val_loss: 0.3353 - val_accuracy: 0.8889 - lr: 1.0240e-05
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# # Classification

# %%
import os
from pathlib import Path
import shutil
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Load the trained model
model_name = "Fashion_modelV3"
model = tf.keras.models.load_model(model_name)

# Define the class names
class_names = ["T-shirt/top", "Trousers", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle Boot"]

# Define the image folder
folder = "imageFolder"

#function to crop and square an image to a specified size so that it doesn't become distorted
def crop_square(img, size, interpolation=cv2.INTER_AREA):
    h, w = img.shape[:2]
    min_size = np.amin([h,w])

    # Centralize and crop
    crop_img = img[int(h/2-min_size/2):int(h/2+min_size/2), int(w/2-min_size/2):int(w/2+min_size/2)]
    return cv2.resize(crop_img, (size, size), interpolation=interpolation)

# Function to preprocess the image
def preprocess_image(image_path):
    # Load the image
    img = cv2.imread(image_path)
    # Resize the image to 28x28
    img = crop_square(img, 28)
    # Convert the image to grayscale
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.bitwise_not(img)
    # Normalize the image
    img = img / 255.0
    # Reshape the image to (28, 28, 1)
    return img

def predict_image(image_path):
    # Preprocess the image
    img = preprocess_image(image_path)
    # Make a prediction
    y_prob = model.predict(img.reshape(1, 28,28))                                                                                                                                                                                                                           # type: ignore

    #print the probabilities
    print("Probabilities:\n")
    for i in range(len(class_names)):
        probability = float(tf.squeeze(y_prob)[i])*100                                                                                                                                                                                                                      # type: ignore
        rounded_probability = np.round(probability, decimals=1)
        print(f"{class_names[i]}: {rounded_probability}%")

    y_pred = np.argmax(y_prob[0])
    # return the class name
    return class_names[y_pred]




# Copy the respective image into a new folder Right or Wrong depending on the prediction. These folders are created for the respective model used for the prediction
def copy_image(image_path, model_name, label):
    # Get the image file name and extension
    image_filename = os.path.basename(image_path)

    label = label.replace("/","_") #"T-shirt/Top" can't be a folder name
    
    # Create the new folder path based on the model name and correctness
    new_folder = Path('Predictions_allClasses', model_name, label)
    
    # Create the new folder if it doesn't exist
    new_folder.mkdir(parents=True, exist_ok=True)
    
    # Construct the new image path
    new_image_path = new_folder / image_filename
    
    # Copy the image to the new path
    shutil.copy(image_path, new_image_path)
    
    print(f"Image copied to: {new_image_path}")


#############
# Main function: Predicts every image form the image folder and creates a copy in a respective folder
#############
def main():

    # Iterate over each file in the folder
    for filename in os.listdir(folder): # type: ignore
        image_path = os.path.join(folder, filename)
        print(f"Choosen image: {image_path}\n")

        #predict the label
        prediction = predict_image(image_path)
        print(f"\nPrediciton: {prediction}")

        if os.path.isfile(image_path):
            copy_image(image_path, model_name, prediction)



if __name__ == "__main__":
    main()
# Out:
# Choosen image: imageFolder/hgnvbnvb.jpg
#
# 1/1 [==============================] - 0s 106ms/step
# Probabilities:
#
# T-shirt/top: 0.3%
# Trousers: 0.0%
# Pullover: 62.3%
# Dress: 0.0%
# Coat: 33.5%
# Sandal: 0.0%
# Shirt: 3.9%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Pullover
# Image copied to: Predictions_allClasses/Fashion_modelV3/Pullover/hgnvbnvb.jpg
# Choosen image: imageFolder/jhljh,,bnm.jpg
#
# 1/1 [==============================] - 0s 27ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 24.7%
# Dress: 0.0%
# Coat: 69.3%
# Sandal: 0.0%
# Shirt: 6.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Coat
# Image copied to: Predictions_allClasses/Fashion_modelV3/Coat/jhljh,,bnm.jpg
# Choosen image: imageFolder/gdfvbdvd.jpg
#
# 1/1 [==============================] - 0s 24ms/step
# Probabilities:
#
# T-shirt/top: 0.2%
# Trousers: 0.0%
# Pullover: 35.4%
# Dress: 0.1%
# Coat: 3.0%
# Sandal: 0.0%
# Shirt: 61.1%
# Sneaker: 0.0%
# Bag: 0.2%
# Ankle Boot: 0.0%
#
# Prediciton: Shirt
# Image copied to: Predictions_allClasses/Fashion_modelV3/Shirt/gdfvbdvd.jpg
# Choosen image: imageFolder/HGNHGNHG.jpg
#
# 1/1 [==============================] - 0s 29ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 14.9%
# Dress: 0.0%
# Coat: 78.6%
# Sandal: 0.0%
# Shirt: 6.5%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Coat
# Image copied to: Predictions_allClasses/Fashion_modelV3/Coat/HGNHGNHG.jpg
# Choosen image: imageFolder/cascacew.jpg
#
# 1/1 [==============================] - 0s 24ms/step
# Probabilities:
#
# T-shirt/top: 0.4%
# Trousers: 1.4%
# Pullover: 0.0%
# Dress: 97.9%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.3%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/cascacew.jpg
# Choosen image: imageFolder/scdscsd.jpg
#
# 1/1 [==============================] - 0s 23ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 20.4%
# Shirt: 0.0%
# Sneaker: 79.6%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Sneaker
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sneaker/scdscsd.jpg
# Choosen image: imageFolder/frdescs.jpg
#
# 1/1 [==============================] - 0s 23ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 46.1%
# Shirt: 0.0%
# Sneaker: 53.8%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Sneaker
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sneaker/frdescs.jpg
# Choosen image: imageFolder/ngfngfb.jpg
#
# 1/1 [==============================] - 0s 28ms/step
# Probabilities:
#
# T-shirt/top: 0.1%
# Trousers: 0.0%
# Pullover: 0.1%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.1%
# Sneaker: 0.0%
# Bag: 99.7%
# Ankle Boot: 0.0%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/ngfngfb.jpg
# Choosen image: imageFolder/eqwf.jpg
#
# 1/1 [==============================] - 0s 28ms/step
# Probabilities:
#
# T-shirt/top: 0.3%
# Trousers: 65.2%
# Pullover: 0.1%
# Dress: 33.5%
# Coat: 0.3%
# Sandal: 0.0%
# Shirt: 0.3%
# Sneaker: 0.0%
# Bag: 0.3%
# Ankle Boot: 0.0%
#
# Prediciton: Trousers
# Image copied to: Predictions_allClasses/Fashion_modelV3/Trousers/eqwf.jpg
# Choosen image: imageFolder/gwecdsafcs.jpg
#
# 1/1 [==============================] - 0s 26ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 95.8%
# Shirt: 0.0%
# Sneaker: 4.2%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Sandal
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sandal/gwecdsafcs.jpg
# Choosen image: imageFolder/esdadas.jpg
#
# 1/1 [==============================] - 0s 24ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.2%
# Shirt: 0.0%
# Sneaker: 99.8%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Sneaker
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sneaker/esdadas.jpg
# Choosen image: imageFolder/ztjgdvds.jpg
#
# 1/1 [==============================] - 0s 35ms/step
# Probabilities:
#
# T-shirt/top: 0.1%
# Trousers: 0.0%
# Pullover: 16.3%
# Dress: 0.0%
# Coat: 43.9%
# Sandal: 0.0%
# Shirt: 39.6%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Coat
# Image copied to: Predictions_allClasses/Fashion_modelV3/Coat/ztjgdvds.jpg
# Choosen image: imageFolder/jjjjfgb.jpg
#
# 1/1 [==============================] - 0s 23ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 100.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Sandal
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sandal/jjjjfgb.jpg
# Choosen image: imageFolder/afascsa.jpg
#
# 1/1 [==============================] - 0s 23ms/step
# Probabilities:
#
# T-shirt/top: 0.8%
# Trousers: 0.0%
# Pullover: 42.6%
# Dress: 0.8%
# Coat: 13.4%
# Sandal: 0.0%
# Shirt: 40.3%
# Sneaker: 0.0%
# Bag: 2.1%
# Ankle Boot: 0.0%
#
# Prediciton: Pullover
# Image copied to: Predictions_allClasses/Fashion_modelV3/Pullover/afascsa.jpg
# Choosen image: imageFolder/ec-5142438_3.jpg
#
# 1/1 [==============================] - 0s 29ms/step
# Probabilities:
#
# T-shirt/top: 0.1%
# Trousers: 0.0%
# Pullover: 0.5%
# Dress: 0.2%
# Coat: 0.1%
# Sandal: 16.6%
# Shirt: 0.5%
# Sneaker: 58.3%
# Bag: 23.0%
# Ankle Boot: 0.6%
#
# Prediciton: Sneaker
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sneaker/ec-5142438_3.jpg
# Choosen image: imageFolder/2154096_4.webp
#
# 1/1 [==============================] - 0s 25ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.1%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 5.1%
# Shirt: 0.1%
# Sneaker: 23.2%
# Bag: 71.5%
# Ankle Boot: 0.0%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/2154096_4.webp
# Choosen image: imageFolder/2241_hmlgo-cotton-t-shirt-s-s_59397_xl.jpg
#
# 1/1 [==============================] - 0s 25ms/step
# Probabilities:
#
# T-shirt/top: 54.7%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 45.3%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: T-shirt/top
# Image copied to: Predictions_allClasses/Fashion_modelV3/T-shirt_top/2241_hmlgo-cotton-t-shirt-s-s_59397_xl.jpg
# Choosen image: imageFolder/lkjkiuzju.jpg
#
# 1/1 [==============================] - 0s 25ms/step
# Probabilities:
#
# T-shirt/top: 2.8%
# Trousers: 8.4%
# Pullover: 0.4%
# Dress: 85.5%
# Coat: 0.6%
# Sandal: 0.0%
# Shirt: 1.1%
# Sneaker: 0.0%
# Bag: 1.2%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/lkjkiuzju.jpg
# Choosen image: imageFolder/rFfsxfverfe.jpg
#
# 1/1 [==============================] - 0s 29ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 100.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Trousers
# Image copied to: Predictions_allClasses/Fashion_modelV3/Trousers/rFfsxfverfe.jpg
# Choosen image: imageFolder/rbddfbv.jpg
#
# 1/1 [==============================] - 0s 29ms/step
# Probabilities:
#
# T-shirt/top: 6.2%
# Trousers: 0.5%
# Pullover: 0.1%
# Dress: 92.4%
# Coat: 0.1%
# Sandal: 0.0%
# Shirt: 0.6%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/rbddfbv.jpg
# Choosen image: imageFolder/nfcvbtfdvgfd.jpg
#
# 1/1 [==============================] - 0s 27ms/step
# Probabilities:
#
# T-shirt/top: 1.6%
# Trousers: 0.0%
# Pullover: 0.1%
# Dress: 97.3%
# Coat: 0.3%
# Sandal: 0.0%
# Shirt: 0.7%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/nfcvbtfdvgfd.jpg
# Choosen image: imageFolder/EC110GP__56766.1459404193.1280.1280_600x.webp
#
# 1/1 [==============================] - 0s 28ms/step
# Probabilities:
#
# T-shirt/top: 0.1%
# Trousers: 0.0%
# Pullover: 0.1%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.2%
# Sneaker: 0.0%
# Bag: 99.6%
# Ankle Boot: 0.0%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/EC110GP__56766.1459404193.1280.1280_600x.webp
# Choosen image: imageFolder/gfjrthfgdhgf.jpg
#
# 1/1 [==============================] - 0s 23ms/step
# Probabilities:
#
# T-shirt/top: 3.3%
# Trousers: 0.0%
# Pullover: 72.8%
# Dress: 0.0%
# Coat: 0.7%
# Sandal: 0.0%
# Shirt: 12.7%
# Sneaker: 0.0%
# Bag: 10.6%
# Ankle Boot: 0.0%
#
# Prediciton: Pullover
# Image copied to: Predictions_allClasses/Fashion_modelV3/Pullover/gfjrthfgdhgf.jpg
# Choosen image: imageFolder/adsd.jpg
#
# 1/1 [==============================] - 0s 25ms/step
# Probabilities:
#
# T-shirt/top: 0.1%
# Trousers: 0.0%
# Pullover: 0.6%
# Dress: 0.0%
# Coat: 0.1%
# Sandal: 62.6%
# Shirt: 0.7%
# Sneaker: 27.9%
# Bag: 7.7%
# Ankle Boot: 0.2%
#
# Prediciton: Sandal
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sandal/adsd.jpg
# Choosen image: imageFolder/dsvsvsdvxsy.jpg
#
# 1/1 [==============================] - 0s 22ms/step
# Probabilities:
#
# T-shirt/top: 4.0%
# Trousers: 0.1%
# Pullover: 47.6%
# Dress: 2.0%
# Coat: 10.7%
# Sandal: 0.0%
# Shirt: 34.4%
# Sneaker: 0.0%
# Bag: 1.3%
# Ankle Boot: 0.0%
#
# Prediciton: Pullover
# Image copied to: Predictions_allClasses/Fashion_modelV3/Pullover/dsvsvsdvxsy.jpg
# Choosen image: imageFolder/asfadsad.jpg
#
# 1/1 [==============================] - 0s 29ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 3.4%
# Shirt: 0.0%
# Sneaker: 1.3%
# Bag: 0.0%
# Ankle Boot: 95.3%
#
# Prediciton: Ankle Boot
# Image copied to: Predictions_allClasses/Fashion_modelV3/Ankle Boot/asfadsad.jpg
# Choosen image: imageFolder/fdvsvs.jpg
#
# 1/1 [==============================] - 0s 40ms/step
# Probabilities:
#
# T-shirt/top: 1.5%
# Trousers: 0.4%
# Pullover: 0.2%
# Dress: 95.4%
# Coat: 0.1%
# Sandal: 0.0%
# Shirt: 2.4%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/fdvsvs.jpg
# Choosen image: imageFolder/bdfvsvds.jpg
#
# 1/1 [==============================] - 0s 27ms/step
# Probabilities:
#
# T-shirt/top: 3.9%
# Trousers: 0.1%
# Pullover: 19.9%
# Dress: 0.1%
# Coat: 0.9%
# Sandal: 0.1%
# Shirt: 12.2%
# Sneaker: 0.0%
# Bag: 62.8%
# Ankle Boot: 0.0%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/bdfvsvds.jpg
# Choosen image: imageFolder/rfvdscdsacsa.jpg
#
# 1/1 [==============================] - 0s 38ms/step
# Probabilities:
#
# T-shirt/top: 1.1%
# Trousers: 0.1%
# Pullover: 0.1%
# Dress: 98.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.7%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/rfvdscdsacsa.jpg
# Choosen image: imageFolder/aqdsqawa.jpg
#
# 1/1 [==============================] - 0s 33ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.1%
# Coat: 0.0%
# Sandal: 24.8%
# Shirt: 0.0%
# Sneaker: 73.4%
# Bag: 0.2%
# Ankle Boot: 1.4%
#
# Prediciton: Sneaker
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sneaker/aqdsqawa.jpg
# Choosen image: imageFolder/EASWFDCAC.jpg
#
# 1/1 [==============================] - 0s 32ms/step
# Probabilities:
#
# T-shirt/top: 2.4%
# Trousers: 0.0%
# Pullover: 81.4%
# Dress: 0.0%
# Coat: 1.1%
# Sandal: 0.0%
# Shirt: 14.1%
# Sneaker: 0.0%
# Bag: 1.1%
# Ankle Boot: 0.0%
#
# Prediciton: Pullover
# Image copied to: Predictions_allClasses/Fashion_modelV3/Pullover/EASWFDCAC.jpg
# Choosen image: imageFolder/swfwefdw.jpg
#
# 1/1 [==============================] - 0s 27ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 100.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Sandal
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sandal/swfwefdw.jpg
# Choosen image: imageFolder/rdfsfsdvdcs.jpg
#
# 1/1 [==============================] - 0s 25ms/step
# Probabilities:
#
# T-shirt/top: 2.0%
# Trousers: 0.1%
# Pullover: 4.2%
# Dress: 0.7%
# Coat: 0.5%
# Sandal: 5.0%
# Shirt: 3.4%
# Sneaker: 0.2%
# Bag: 83.4%
# Ankle Boot: 0.5%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/rdfsfsdvdcs.jpg
# Choosen image: imageFolder/DMX15475-Brandit-m-65-Jacke-3101-11-vorne-NS-2_600x600.webp
#
# 1/1 [==============================] - 0s 26ms/step
# Probabilities:
#
# T-shirt/top: 0.1%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 3.1%
# Coat: 0.0%
# Sandal: 95.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.1%
# Ankle Boot: 1.7%
#
# Prediciton: Sandal
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sandal/DMX15475-Brandit-m-65-Jacke-3101-11-vorne-NS-2_600x600.webp
# Choosen image: imageFolder/0bbd27874bb83ff2b45900125c7a0252.webp
#
# 1/1 [==============================] - 0s 25ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 30.9%
# Dress: 0.0%
# Coat: 62.0%
# Sandal: 0.0%
# Shirt: 7.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Coat
# Image copied to: Predictions_allClasses/Fashion_modelV3/Coat/0bbd27874bb83ff2b45900125c7a0252.webp
# Choosen image: imageFolder/ghncncvbgf.jpg
#
# 1/1 [==============================] - 0s 31ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 89.2%
# Dress: 0.0%
# Coat: 1.4%
# Sandal: 0.0%
# Shirt: 9.4%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Pullover
# Image copied to: Predictions_allClasses/Fashion_modelV3/Pullover/ghncncvbgf.jpg
# Choosen image: imageFolder/awfadsad.jpg
#
# 1/1 [==============================] - 0s 32ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 100.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Trousers
# Image copied to: Predictions_allClasses/Fashion_modelV3/Trousers/awfadsad.jpg
# Choosen image: imageFolder/FCSCVDSV.jpg
#
# 1/1 [==============================] - 0s 27ms/step
# Probabilities:
#
# T-shirt/top: 0.1%
# Trousers: 0.0%
# Pullover: 21.0%
# Dress: 0.0%
# Coat: 55.6%
# Sandal: 0.0%
# Shirt: 23.2%
# Sneaker: 0.0%
# Bag: 0.1%
# Ankle Boot: 0.0%
#
# Prediciton: Coat
# Image copied to: Predictions_allClasses/Fashion_modelV3/Coat/FCSCVDSV.jpg
# Choosen image: imageFolder/opolulil.jpg
#
# 1/1 [==============================] - 0s 32ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 100.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Trousers
# Image copied to: Predictions_allClasses/Fashion_modelV3/Trousers/opolulil.jpg
# Choosen image: imageFolder/superdry-source-retro-jacket-w5010967a.jpg
#
# 1/1 [==============================] - 0s 27ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 12.1%
# Dress: 0.0%
# Coat: 87.2%
# Sandal: 0.0%
# Shirt: 0.7%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Coat
# Image copied to: Predictions_allClasses/Fashion_modelV3/Coat/superdry-source-retro-jacket-w5010967a.jpg
# Choosen image: imageFolder/dfbbvfd.jpg
#
# 1/1 [==============================] - 0s 23ms/step
# Probabilities:
#
# T-shirt/top: 0.1%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 1.2%
# Coat: 0.0%
# Sandal: 38.3%
# Shirt: 0.0%
# Sneaker: 19.6%
# Bag: 0.7%
# Ankle Boot: 40.1%
#
# Prediciton: Ankle Boot
# Image copied to: Predictions_allClasses/Fashion_modelV3/Ankle Boot/dfbbvfd.jpg
# Choosen image: imageFolder/ngegverg.jpg
#
# 1/1 [==============================] - 0s 22ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 4.2%
# Shirt: 0.0%
# Sneaker: 91.8%
# Bag: 0.0%
# Ankle Boot: 3.9%
#
# Prediciton: Sneaker
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sneaker/ngegverg.jpg
# Choosen image: imageFolder/aodhpoihp.jpg
#
# 1/1 [==============================] - 0s 29ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 100.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Trousers
# Image copied to: Predictions_allClasses/Fashion_modelV3/Trousers/aodhpoihp.jpg
# Choosen image: imageFolder/06abbdd37091.jpg
#
# 1/1 [==============================] - 0s 24ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.9%
# Shirt: 0.0%
# Sneaker: 99.1%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Sneaker
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sneaker/06abbdd37091.jpg
# Choosen image: imageFolder/sadoichoaihc.jpg
#
# 1/1 [==============================] - 0s 31ms/step
# Probabilities:
#
# T-shirt/top: 0.2%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 95.6%
# Coat: 0.1%
# Sandal: 0.0%
# Shirt: 4.1%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/sadoichoaihc.jpg
# Choosen image: imageFolder/thbdsfvvsdcvs.jpg
#
# 1/1 [==============================] - 0s 25ms/step
# Probabilities:
#
# T-shirt/top: 4.0%
# Trousers: 0.4%
# Pullover: 1.0%
# Dress: 90.9%
# Coat: 0.6%
# Sandal: 0.0%
# Shirt: 2.8%
# Sneaker: 0.0%
# Bag: 0.2%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/thbdsfvvsdcvs.jpg
# Choosen image: imageFolder/gssdfsd.jpg
#
# 1/1 [==============================] - 0s 32ms/step
# Probabilities:
#
# T-shirt/top: 0.1%
# Trousers: 0.0%
# Pullover: 48.1%
# Dress: 0.0%
# Coat: 7.1%
# Sandal: 0.0%
# Shirt: 44.6%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Pullover
# Image copied to: Predictions_allClasses/Fashion_modelV3/Pullover/gssdfsd.jpg
# Choosen image: imageFolder/AWDASD.jpg
#
# 1/1 [==============================] - 0s 43ms/step
# Probabilities:
#
# T-shirt/top: 10.1%
# Trousers: 0.2%
# Pullover: 13.3%
# Dress: 2.2%
# Coat: 7.9%
# Sandal: 0.0%
# Shirt: 9.2%
# Sneaker: 0.0%
# Bag: 57.1%
# Ankle Boot: 0.0%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/AWDASD.jpg
# Choosen image: imageFolder/terddwscfsa.jpg
#
# 1/1 [==============================] - 0s 26ms/step
# Probabilities:
#
# T-shirt/top: 0.1%
# Trousers: 0.0%
# Pullover: 73.5%
# Dress: 0.0%
# Coat: 25.8%
# Sandal: 0.0%
# Shirt: 0.7%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Pullover
# Image copied to: Predictions_allClasses/Fashion_modelV3/Pullover/terddwscfsa.jpg
# Choosen image: imageFolder/jhghgfdb.jpg
#
# 1/1 [==============================] - 0s 24ms/step
# Probabilities:
#
# T-shirt/top: 13.2%
# Trousers: 0.1%
# Pullover: 34.6%
# Dress: 1.1%
# Coat: 0.8%
# Sandal: 0.0%
# Shirt: 49.4%
# Sneaker: 0.0%
# Bag: 0.8%
# Ankle Boot: 0.0%
#
# Prediciton: Shirt
# Image copied to: Predictions_allClasses/Fashion_modelV3/Shirt/jhghgfdb.jpg
# Choosen image: imageFolder/qffsd.jpg
#
# 1/1 [==============================] - 0s 23ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 100.0%
# Ankle Boot: 0.0%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/qffsd.jpg
# Choosen image: imageFolder/oiuhaoidhw.jpg
#
# 1/1 [==============================] - 0s 24ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 100.0%
# Ankle Boot: 0.0%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/oiuhaoidhw.jpg
# Choosen image: imageFolder/j,hjmhgng.jpg
#
# 1/1 [==============================] - 0s 23ms/step
# Probabilities:
#
# T-shirt/top: 3.5%
# Trousers: 0.2%
# Pullover: 6.9%
# Dress: 3.3%
# Coat: 1.4%
# Sandal: 0.1%
# Shirt: 3.8%
# Sneaker: 0.0%
# Bag: 80.8%
# Ankle Boot: 0.0%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/j,hjmhgng.jpg
# Choosen image: imageFolder/ssfada.jpg
#
# 1/1 [==============================] - 0s 26ms/step
# Probabilities:
#
# T-shirt/top: 3.4%
# Trousers: 0.6%
# Pullover: 20.9%
# Dress: 31.4%
# Coat: 28.6%
# Sandal: 0.0%
# Shirt: 11.5%
# Sneaker: 0.0%
# Bag: 3.6%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/ssfada.jpg
# Choosen image: imageFolder/jlhkljgk.jpg
#
# 1/1 [==============================] - 0s 30ms/step
# Probabilities:
#
# T-shirt/top: 0.1%
# Trousers: 87.7%
# Pullover: 0.0%
# Dress: 12.1%
# Coat: 0.1%
# Sandal: 0.0%
# Shirt: 0.1%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Trousers
# Image copied to: Predictions_allClasses/Fashion_modelV3/Trousers/jlhkljgk.jpg
# Choosen image: imageFolder/rweVSVFSVS.jpg
#
# 1/1 [==============================] - 0s 25ms/step
# Probabilities:
#
# T-shirt/top: 0.1%
# Trousers: 0.0%
# Pullover: 60.4%
# Dress: 0.0%
# Coat: 28.0%
# Sandal: 0.0%
# Shirt: 11.5%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Pullover
# Image copied to: Predictions_allClasses/Fashion_modelV3/Pullover/rweVSVFSVS.jpg
# Choosen image: imageFolder/gfdscvdsvsd.jpg
#
# 1/1 [==============================] - 0s 24ms/step
# Probabilities:
#
# T-shirt/top: 1.8%
# Trousers: 0.9%
# Pullover: 0.1%
# Dress: 96.2%
# Coat: 0.1%
# Sandal: 0.0%
# Shirt: 0.7%
# Sneaker: 0.0%
# Bag: 0.1%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/gfdscvdsvsd.jpg
# Choosen image: imageFolder/gfdbfbdf.jpg
#
# 1/1 [==============================] - 0s 23ms/step
# Probabilities:
#
# T-shirt/top: 0.5%
# Trousers: 0.0%
# Pullover: 4.1%
# Dress: 0.2%
# Coat: 0.7%
# Sandal: 3.8%
# Shirt: 2.2%
# Sneaker: 0.8%
# Bag: 87.5%
# Ankle Boot: 0.1%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/gfdbfbdf.jpg
# Choosen image: imageFolder/fcaiuhfdoiuwazhg.jpg
#
# 1/1 [==============================] - 0s 32ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 95.3%
# Bag: 0.0%
# Ankle Boot: 4.6%
#
# Prediciton: Sneaker
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sneaker/fcaiuhfdoiuwazhg.jpg
# Choosen image: imageFolder/hfrgfdgfhfg.jpg
#
# 1/1 [==============================] - 0s 26ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 81.8%
# Shirt: 0.0%
# Sneaker: 0.1%
# Bag: 0.0%
# Ankle Boot: 18.1%
#
# Prediciton: Sandal
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sandal/hfrgfdgfhfg.jpg
# Choosen image: imageFolder/fgfgdvfvfdevcscsd.jpg
#
# 1/1 [==============================] - 0s 22ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 35.9%
# Shirt: 0.0%
# Sneaker: 26.5%
# Bag: 0.2%
# Ankle Boot: 37.5%
#
# Prediciton: Ankle Boot
# Image copied to: Predictions_allClasses/Fashion_modelV3/Ankle Boot/fgfgdvfvfdevcscsd.jpg
# Choosen image: imageFolder/61sqb4gPRXL._AC_SX679_.jpg
#
# 1/1 [==============================] - 0s 30ms/step
# Probabilities:
#
# T-shirt/top: 5.9%
# Trousers: 0.3%
# Pullover: 17.7%
# Dress: 0.2%
# Coat: 0.6%
# Sandal: 0.0%
# Shirt: 14.1%
# Sneaker: 0.0%
# Bag: 61.2%
# Ankle Boot: 0.0%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/61sqb4gPRXL._AC_SX679_.jpg
# Choosen image: imageFolder/okjdofjodjo.jpg
#
# 1/1 [==============================] - 0s 25ms/step
# Probabilities:
#
# T-shirt/top: 0.2%
# Trousers: 0.4%
# Pullover: 0.0%
# Dress: 99.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.3%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/okjdofjodjo.jpg
# Choosen image: imageFolder/ettqvgqerg.jpg
#
# 1/1 [==============================] - 0s 24ms/step
# Probabilities:
#
# T-shirt/top: 92.8%
# Trousers: 0.0%
# Pullover: 0.4%
# Dress: 0.7%
# Coat: 0.1%
# Sandal: 0.0%
# Shirt: 6.1%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: T-shirt/top
# Image copied to: Predictions_allClasses/Fashion_modelV3/T-shirt_top/ettqvgqerg.jpg
# Choosen image: imageFolder/sdfscs.jpg
#
# 1/1 [==============================] - 0s 24ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 100.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Sandal
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sandal/sdfscs.jpg
# Choosen image: imageFolder/csaCACSACAS.jpg
#
# 1/1 [==============================] - 0s 24ms/step
# Probabilities:
#
# T-shirt/top: 1.5%
# Trousers: 0.1%
# Pullover: 2.5%
# Dress: 1.1%
# Coat: 0.7%
# Sandal: 0.0%
# Shirt: 1.4%
# Sneaker: 0.0%
# Bag: 92.7%
# Ankle Boot: 0.0%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/csaCACSACAS.jpg
# Choosen image: imageFolder/wwergfgwer.jpg
#
# 1/1 [==============================] - 0s 36ms/step
# Probabilities:
#
# T-shirt/top: 9.9%
# Trousers: 0.0%
# Pullover: 36.1%
# Dress: 0.1%
# Coat: 6.4%
# Sandal: 0.0%
# Shirt: 47.3%
# Sneaker: 0.0%
# Bag: 0.2%
# Ankle Boot: 0.0%
#
# Prediciton: Shirt
# Image copied to: Predictions_allClasses/Fashion_modelV3/Shirt/wwergfgwer.jpg
# Choosen image: imageFolder/rtgscdsacs.jpg
#
# 1/1 [==============================] - 0s 25ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 100.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/rtgscdsacs.jpg
# Choosen image: imageFolder/dsefdwedf.jpg
#
# 1/1 [==============================] - 0s 23ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 100.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/dsefdwedf.jpg
# Choosen image: imageFolder/QFDWQfsa.jpg
#
# 1/1 [==============================] - 0s 23ms/step
# Probabilities:
#
# T-shirt/top: 91.5%
# Trousers: 0.0%
# Pullover: 0.1%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 8.5%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: T-shirt/top
# Image copied to: Predictions_allClasses/Fashion_modelV3/T-shirt_top/QFDWQfsa.jpg
# Choosen image: imageFolder/scadscas.jpg
#
# 1/1 [==============================] - 0s 24ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 4.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 95.9%
# Ankle Boot: 0.0%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/scadscas.jpg
# Choosen image: imageFolder/reehf.jpg
#
# 1/1 [==============================] - 0s 37ms/step
# Probabilities:
#
# T-shirt/top: 96.3%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 3.7%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: T-shirt/top
# Image copied to: Predictions_allClasses/Fashion_modelV3/T-shirt_top/reehf.jpg
# Choosen image: imageFolder/dqsfqwefq.jpg
#
# 1/1 [==============================] - 0s 25ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 51.9%
# Shirt: 0.0%
# Sneaker: 48.0%
# Bag: 0.0%
# Ankle Boot: 0.1%
#
# Prediciton: Sandal
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sandal/dqsfqwefq.jpg
# Choosen image: imageFolder/wedsvsc yycxyyx.jpg
#
# 1/1 [==============================] - 0s 26ms/step
# Probabilities:
#
# T-shirt/top: 19.4%
# Trousers: 0.1%
# Pullover: 0.0%
# Dress: 61.6%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 18.9%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/wedsvsc yycxyyx.jpg
# Choosen image: imageFolder/scdsaxax.jpg
#
# 1/1 [==============================] - 0s 23ms/step
# Probabilities:
#
# T-shirt/top: 0.3%
# Trousers: 0.5%
# Pullover: 0.0%
# Dress: 99.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.1%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/scdsaxax.jpg
# Choosen image: imageFolder/adascva.jpg
#
# 1/1 [==============================] - 0s 33ms/step
# Probabilities:
#
# T-shirt/top: 5.6%
# Trousers: 0.3%
# Pullover: 2.7%
# Dress: 2.7%
# Coat: 0.8%
# Sandal: 0.0%
# Shirt: 2.4%
# Sneaker: 0.0%
# Bag: 85.6%
# Ankle Boot: 0.0%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/adascva.jpg
# Choosen image: imageFolder/adlihlkjhfds.jpg
#
# 1/1 [==============================] - 0s 32ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 100.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Trousers
# Image copied to: Predictions_allClasses/Fashion_modelV3/Trousers/adlihlkjhfds.jpg
# Choosen image: imageFolder/geasgtkzt.jpg
#
# 1/1 [==============================] - 0s 26ms/step
# Probabilities:
#
# T-shirt/top: 49.4%
# Trousers: 0.0%
# Pullover: 0.5%
# Dress: 0.1%
# Coat: 0.1%
# Sandal: 0.0%
# Shirt: 49.9%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Shirt
# Image copied to: Predictions_allClasses/Fashion_modelV3/Shirt/geasgtkzt.jpg
# Choosen image: imageFolder/oijhpihp.jpg
#
# 1/1 [==============================] - 0s 25ms/step
# Probabilities:
#
# T-shirt/top: 2.0%
# Trousers: 2.7%
# Pullover: 0.1%
# Dress: 93.3%
# Coat: 0.0%
# Sandal: 0.1%
# Shirt: 1.5%
# Sneaker: 0.0%
# Bag: 0.2%
# Ankle Boot: 0.1%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/oijhpihp.jpg
# Choosen image: imageFolder/uzkjgfrftfdhg.jpg
#
# 1/1 [==============================] - 0s 30ms/step
# Probabilities:
#
# T-shirt/top: 14.4%
# Trousers: 0.2%
# Pullover: 1.3%
# Dress: 55.0%
# Coat: 4.9%
# Sandal: 0.0%
# Shirt: 24.2%
# Sneaker: 0.0%
# Bag: 0.1%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/uzkjgfrftfdhg.jpg
# Choosen image: imageFolder/afsdasdsad.jpg
#
# 1/1 [==============================] - 0s 33ms/step
# Probabilities:
#
# T-shirt/top: 0.4%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 4.6%
# Coat: 0.0%
# Sandal: 62.1%
# Shirt: 0.0%
# Sneaker: 1.3%
# Bag: 0.9%
# Ankle Boot: 30.6%
#
# Prediciton: Sandal
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sandal/afsdasdsad.jpg
# Choosen image: imageFolder/fscdscds.jpg
#
# 1/1 [==============================] - 0s 34ms/step
# Probabilities:
#
# T-shirt/top: 11.4%
# Trousers: 1.8%
# Pullover: 0.1%
# Dress: 85.1%
# Coat: 0.2%
# Sandal: 0.0%
# Shirt: 1.4%
# Sneaker: 0.0%
# Bag: 0.1%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/fscdscds.jpg
# Choosen image: imageFolder/wregfwsvgdsvgwfe.jpg
#
# 1/1 [==============================] - 0s 22ms/step
# Probabilities:
#
# T-shirt/top: 99.3%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.7%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: T-shirt/top
# Image copied to: Predictions_allClasses/Fashion_modelV3/T-shirt_top/wregfwsvgdsvgwfe.jpg
# Choosen image: imageFolder/jkjljlk.jpg
#
# 1/1 [==============================] - 0s 23ms/step
# Probabilities:
#
# T-shirt/top: 1.9%
# Trousers: 0.5%
# Pullover: 3.3%
# Dress: 3.0%
# Coat: 0.8%
# Sandal: 66.0%
# Shirt: 2.8%
# Sneaker: 2.5%
# Bag: 14.5%
# Ankle Boot: 4.9%
#
# Prediciton: Sandal
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sandal/jkjljlk.jpg
# Choosen image: imageFolder/wscsdcwer.jpg
#
# 1/1 [==============================] - 0s 26ms/step
# Probabilities:
#
# T-shirt/top: 0.3%
# Trousers: 0.0%
# Pullover: 78.5%
# Dress: 0.1%
# Coat: 20.2%
# Sandal: 0.0%
# Shirt: 0.9%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Pullover
# Image copied to: Predictions_allClasses/Fashion_modelV3/Pullover/wscsdcwer.jpg
# Choosen image: imageFolder/acacaxcy.jpg
#
# 1/1 [==============================] - 0s 27ms/step
# Probabilities:
#
# T-shirt/top: 2.5%
# Trousers: 0.9%
# Pullover: 0.1%
# Dress: 95.7%
# Coat: 0.1%
# Sandal: 0.0%
# Shirt: 0.6%
# Sneaker: 0.0%
# Bag: 0.1%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/acacaxcy.jpg
# Choosen image: imageFolder/dsafsac.jpg
#
# 1/1 [==============================] - 0s 27ms/step
# Probabilities:
#
# T-shirt/top: 1.5%
# Trousers: 0.0%
# Pullover: 42.8%
# Dress: 0.0%
# Coat: 2.1%
# Sandal: 0.0%
# Shirt: 53.3%
# Sneaker: 0.0%
# Bag: 0.3%
# Ankle Boot: 0.0%
#
# Prediciton: Shirt
# Image copied to: Predictions_allClasses/Fashion_modelV3/Shirt/dsafsac.jpg
# Choosen image: imageFolder/lizujztjhtnb.jpg
#
# 1/1 [==============================] - 0s 24ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 4.7%
# Shirt: 0.0%
# Sneaker: 23.2%
# Bag: 0.1%
# Ankle Boot: 72.0%
#
# Prediciton: Ankle Boot
# Image copied to: Predictions_allClasses/Fashion_modelV3/Ankle Boot/lizujztjhtnb.jpg
# Choosen image: imageFolder/rrngfbf.jpg
#
# 1/1 [==============================] - 0s 32ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 95.7%
# Shirt: 0.0%
# Sneaker: 2.7%
# Bag: 0.0%
# Ankle Boot: 1.6%
#
# Prediciton: Sandal
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sandal/rrngfbf.jpg
# Choosen image: imageFolder/adadadad.jpg
#
# 1/1 [==============================] - 0s 25ms/step
# Probabilities:
#
# T-shirt/top: 26.2%
# Trousers: 0.1%
# Pullover: 39.7%
# Dress: 0.6%
# Coat: 0.8%
# Sandal: 0.0%
# Shirt: 30.7%
# Sneaker: 0.0%
# Bag: 2.0%
# Ankle Boot: 0.0%
#
# Prediciton: Pullover
# Image copied to: Predictions_allClasses/Fashion_modelV3/Pullover/adadadad.jpg
# Choosen image: imageFolder/ASASA.jpg
#
# 1/1 [==============================] - 0s 37ms/step
# Probabilities:
#
# T-shirt/top: 0.2%
# Trousers: 0.0%
# Pullover: 0.3%
# Dress: 0.1%
# Coat: 0.1%
# Sandal: 0.0%
# Shirt: 0.5%
# Sneaker: 0.0%
# Bag: 98.8%
# Ankle Boot: 0.0%
#
# Prediciton: Bag
# Image copied to: Predictions_allClasses/Fashion_modelV3/Bag/ASASA.jpg
# Choosen image: imageFolder/afasadasdawe.jpg
#
# 1/1 [==============================] - 0s 46ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 100.0%
#
# Prediciton: Ankle Boot
# Image copied to: Predictions_allClasses/Fashion_modelV3/Ankle Boot/afasadasdawe.jpg
# Choosen image: imageFolder/ohogfhogoqgh.jpg
#
# 1/1 [==============================] - 0s 34ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 100.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 0.0%
# Shirt: 0.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Trousers
# Image copied to: Predictions_allClasses/Fashion_modelV3/Trousers/ohogfhogoqgh.jpg
# Choosen image: imageFolder/scvdvds.jpg
#
# 1/1 [==============================] - 0s 34ms/step
# Probabilities:
#
# T-shirt/top: 1.8%
# Trousers: 0.2%
# Pullover: 0.1%
# Dress: 11.9%
# Coat: 0.4%
# Sandal: 39.0%
# Shirt: 0.6%
# Sneaker: 16.4%
# Bag: 1.7%
# Ankle Boot: 27.8%
#
# Prediciton: Sandal
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sandal/scvdvds.jpg
# Choosen image: imageFolder/gdecdasc.jpg
#
# 1/1 [==============================] - 0s 33ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 29.5%
# Dress: 0.0%
# Coat: 70.3%
# Sandal: 0.0%
# Shirt: 0.2%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Coat
# Image copied to: Predictions_allClasses/Fashion_modelV3/Coat/gdecdasc.jpg
# Choosen image: imageFolder/qdqdsadwdqwd.jpg
#
# 1/1 [==============================] - 0s 33ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 8.3%
# Shirt: 0.0%
# Sneaker: 80.5%
# Bag: 0.2%
# Ankle Boot: 11.0%
#
# Prediciton: Sneaker
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sneaker/qdqdsadwdqwd.jpg
# Choosen image: imageFolder/fdsvscdsc.jpg
#
# 1/1 [==============================] - 0s 37ms/step
# Probabilities:
#
# T-shirt/top: 0.2%
# Trousers: 0.1%
# Pullover: 0.7%
# Dress: 6.2%
# Coat: 80.8%
# Sandal: 0.0%
# Shirt: 0.1%
# Sneaker: 0.0%
# Bag: 11.9%
# Ankle Boot: 0.0%
#
# Prediciton: Coat
# Image copied to: Predictions_allClasses/Fashion_modelV3/Coat/fdsvscdsc.jpg
# Choosen image: imageFolder/poujpdhoij.jpg
#
# 1/1 [==============================] - 0s 33ms/step
# Probabilities:
#
# T-shirt/top: 0.2%
# Trousers: 0.1%
# Pullover: 1.7%
# Dress: 67.6%
# Coat: 27.3%
# Sandal: 0.0%
# Shirt: 3.0%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Dress
# Image copied to: Predictions_allClasses/Fashion_modelV3/Dress/poujpdhoij.jpg
# Choosen image: imageFolder/grcdfsfd.webp
#
# 1/1 [==============================] - 0s 40ms/step
# Probabilities:
#
# T-shirt/top: 0.0%
# Trousers: 0.0%
# Pullover: 0.0%
# Dress: 0.0%
# Coat: 0.0%
# Sandal: 74.5%
# Shirt: 0.0%
# Sneaker: 25.1%
# Bag: 0.0%
# Ankle Boot: 0.4%
#
# Prediciton: Sandal
# Image copied to: Predictions_allClasses/Fashion_modelV3/Sandal/grcdfsfd.webp
# Choosen image: imageFolder/adcxsacx.jpg
#
# 1/1 [==============================] - 0s 39ms/step
# Probabilities:
#
# T-shirt/top: 0.4%
# Trousers: 0.0%
# Pullover: 76.5%
# Dress: 0.0%
# Coat: 4.3%
# Sandal: 0.0%
# Shirt: 18.8%
# Sneaker: 0.0%
# Bag: 0.0%
# Ankle Boot: 0.0%
#
# Prediciton: Pullover
# Image copied to: Predictions_allClasses/Fashion_modelV3/Pullover/adcxsacx.jpg

# %% [markdown]
# # Demonstration_DataAugmenter

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist# type: ignore
from tensorflow.keras.preprocessing.image import ImageDataGenerator# type: ignore
import matplotlib.pyplot as plt
import numpy as np

# Load the Fashion MNIST dataset
(train_data, train_labels) , (test_data, test_labels) = fashion_mnist.load_data()

# Normalize the data
train_data_norm = train_data / 255.0
test_data_norm = test_data / 255.0

def add_noise(image):
    noise = np.random.normal(loc=0, scale=0.02, size=image.shape)
    noisy_image = image + noise
    return np.clip(noisy_image, 0, 1)

# Create an instance of the ImageDataGenerator class for data augmentation
data_augmenter = ImageDataGenerator(
    rotation_range=10,  # rotate the image up to 10 degrees
    width_shift_range=0.05,  
    height_shift_range=0.05,  
    horizontal_flip=True,  # flip the image horizontally
    vertical_flip=False,  # do not flip the image vertically
    zoom_range=0.05,  # zoom in/out up to 5%
    fill_mode='nearest',  # fill gaps in the image with the nearest pixel
    preprocessing_function=add_noise  # Add the add_noise function as the preprocessing function
)

# Fit the data augmenter on the training data
data_augmenter.fit(tf.expand_dims(train_data_norm, 3))

# Display some of the original images
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(10, 5))
for i, ax in enumerate(axes.flat):
    ax.imshow(train_data_norm[i], cmap='binary')
    ax.set_title(f'Label: {train_labels[i]}')
plt.suptitle('Original Images')
plt.show()

# Display some of the augmented images
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(10, 5))
for i, ax in enumerate(axes.flat):
    augmented_image, _ = data_augmenter.flow(
        tf.expand_dims(tf.expand_dims(train_data_norm[i], 0),-1),
        train_labels[i].reshape(1,)
    ).next()
    ax.imshow(augmented_image.squeeze(), cmap='binary')
    ax.set_title(f'Label: {train_labels[i]}')
plt.suptitle('Augmented Images')
plt.show()

# %% [markdown]
# # Demonstration_random_picture_pred

# %%
import cv2
import numpy as np
import os
import random
import matplotlib.pyplot as plt
import tensorflow as tf

# Load the trained model
model_name = "Fashion_modelV3"
model = tf.keras.models.load_model(model_name)

# Define the class names
class_names = ["T-shirt/top", "Trousers", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle Boot"]

# Get a list of image file paths in the folder
folder = "imageFolder"
image_paths = [os.path.join(folder, f) for f in os.listdir(folder) if f.endswith(".jpg") or f.endswith(".jpgeg")]

# Select a random image from the folder
random_image_path = random.choice(image_paths)


#function to crop and square an image to a specified size so that it doesn't become distorted
def crop_square(img, size, interpolation=cv2.INTER_AREA):
    h, w = img.shape[:2]
    min_size = np.amin([h,w])

    # Centralize and crop
    crop_img = img[int(h/2-min_size/2):int(h/2+min_size/2), int(w/2-min_size/2):int(w/2+min_size/2)]

    return cv2.resize(crop_img, (size, size), interpolation=interpolation)

# Function to preprocess the image
def preprocess_image(image_path):
    # Load the image
    img = cv2.imread(image_path)
    # Resize the image to 28x28
    img = crop_square(img, 28)
    # Convert the image to grayscale
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.bitwise_not(img)
    # Normalize the image
    img = img / 255.0
    # Reshape the image to (28, 28, 1)
    return img

def predict_image():
    # Preprocess the image
    img = preprocess_image(random_image_path)
    # Make a prediction
    y_prob = model.predict(img.reshape(1, 28,28)) 

    #print the probabilities
    print("Probabilities:\n")
    for i in range(len(class_names)):
        probability = float(tf.squeeze(y_prob)[i])*100 
        rounded_probability = np.round(probability, decimals=1)
        print(f"{class_names[i]}: {rounded_probability}%")

    y_pred = np.argmax(y_prob[0])
    # return the class name
    return class_names[y_pred]


def main():

    #print(f"Image paths: {image_paths};")  //prints all the image paths
    print(f"Choosen image: {random_image_path}\n")

    #predict the label
    prediction = predict_image()
    print(f"\nPrediciton: {prediction}")


    #show preprocessed and original image
    plt.figure(figsize=(9,9))
    plt.suptitle(model_name)
    plt.subplot(1,2,1)
    plt.imshow(preprocess_image(random_image_path), cmap=plt.cm.binary) 
    plt.title("Preprocessed image")
    plt.xlabel(f"Prediction: {prediction}")


    plt.subplot(1,2,2)
    original_img = cv2.imread(random_image_path)
    original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB) #opencv reads and displays an image as BGR format instead of RGB color format. Whereas matplotlib uses RGB color format to display image --> Converts from BGR to RGB
    plt.imshow(original_img)
    plt.title("Original image")
    plt.show()

if __name__ == "__main__":
    main()

# %% [markdown]
# # Right_Wrong

# %%
import os
from pathlib import Path
import shutil
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Load the trained model
model_name = "Fashion_modelV4"
normalized = True
model = tf.keras.models.load_model(model_name)

# Define the class names
class_names = ["T-shirt/top", "Trousers", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle Boot"]

# Define the image folder
folder = "imageFolder"

#function to crop and square an image to a specified size so that it doesn't become distorted
def crop_square(img, size, interpolation=cv2.INTER_AREA):
    h, w = img.shape[:2]
    min_size = np.amin([h,w])

    # Centralize and crop
    crop_img = img[int(h/2-min_size/2):int(h/2+min_size/2), int(w/2-min_size/2):int(w/2+min_size/2)]
    return cv2.resize(crop_img, (size, size), interpolation=interpolation)

# Function to preprocess the image
def preprocess_image(image_path):
    # Load the image
    img = cv2.imread(image_path)
    # Resize the image to 28x28
    img = crop_square(img, 28)
    # Convert the image to grayscale
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.bitwise_not(img)
    if normalized:
        # Normalize the image
        img = img / 255.0
    # Reshape the image to (28, 28, 1)
    return img

def predict_image(image_path):
    # Preprocess the image
    img = preprocess_image(image_path)
    # Make a prediction
    y_prob = model.predict(img.reshape(1, 28,28))                                                                                                                                                                                                                                                   

    #print the probabilities
    print("Probabilities:\n")
    for i in range(len(class_names)):
        probability = float(tf.squeeze(y_prob)[i])*100                                                                                                                                                                                                                                              
        rounded_probability = np.round(probability, decimals=1)
        print(f"{class_names[i]}: {rounded_probability}%")

    y_pred = np.argmax(y_prob[0])
    # return the class name
    return class_names[y_pred]




# Copy the respective image into a new folder Right or Wrong depending on the prediction. These folders are created for the respective model used for the prediction
def copy_image(image_path, model_name, is_correct):
    # Get the image file name and extension
    image_filename = os.path.basename(image_path)
    
    # Create the new folder path based on the model name and correctness
    new_folder = Path('Predictions_Right_Wrong', model_name, 'Right' if is_correct else 'Wrong')
    
    # Create the new folder if it doesn't exist
    new_folder.mkdir(parents=True, exist_ok=True)
    
    # Construct the new image path
    new_image_path = new_folder / image_filename
    
    # Copy the image to the new path
    shutil.copy(image_path, new_image_path)
    
    print(f"Image copied to: {new_image_path}")

# Computes the accuracy depending on the number of wrong and right predictions
def compute_accuracy(right_count, wrong_count):
    total_count = right_count + wrong_count
    return 0.0 if total_count == 0 else (right_count / total_count) * 100



#############
# Main function: Predicts every image form the image folder. The user then has to input whether the prediciton is right or wrong, after which the image is copied into a respective folder "Right" or "Wrong" for the model. 
# The accuracy of the model is determined using the number of wrong and right pictures
#############
def main():

    right_count = 0
    wrong_count = 0

    # Iterate over each file in the folder
    for filename in os.listdir(folder):
        image_path = os.path.join(folder, filename)
        
        #print(f"Image paths: {image_paths};")  //prints all the image paths
        print(f"Choosen image: {image_path}\n")

        #predict the label
        prediction = predict_image(image_path)
        print(f"\nPrediciton: {prediction}")


        #show preprocessed and original image
        #preprocessed image
        plt.figure(figsize=(9,9))
        plt.suptitle(model_name)
        plt.subplot(1,2,1)
        plt.imshow(preprocess_image(image_path), cmap=plt.cm.binary) 
        plt.title("Preprocessed image")
        plt.xlabel(f"Prediction: {prediction}")
        #original image
        plt.subplot(1,2,2)
        original_img = cv2.imread(image_path)
        original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB) #opencv reads and displays an image as BGR format instead of RGB color format. Whereas matplotlib uses RGB color format to display image --> Converts from BGR to RGB
        plt.imshow(original_img)
        plt.title("Original image")
        plt.show()


        # user input whether the prediction is right or wrong
        user_input = input("Enter 'right' or 'wrong': ")

        if os.path.isfile(image_path):
            if user_input.lower() == "right" or user_input == "1":
                copy_image(image_path, model_name, True)
                right_count += 1
            elif user_input.lower() == "wrong" or user_input == "0":
                copy_image(image_path, model_name, False)
                wrong_count += 1
            else:
                print("Invalid input. Please enter 'right' or 'wrong'.")

    # Compute accuracy
    accuracy = compute_accuracy(right_count, wrong_count)
    print(f"Accuracy: {accuracy}%")



if __name__ == "__main__":
        main()
